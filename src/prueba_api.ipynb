# %%
import requests
import json

user = "John%20Wick"

URL = "http://localhost:8080/{}".format(user)


data = requests.get(url = URL).json()

data
# Out:
# oid': '5de2a5c3606b2bda88819edb'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2a5c3606b2bda88819edd'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2a6a2bf6a32d28305edd8'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2a6a2bf6a32d28305edda'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2a6a2bf6a32d28305eddc'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
# ...

# %%
requests.get('http://localhost:8080/tipo')
# Out:
# <Response [200]>
