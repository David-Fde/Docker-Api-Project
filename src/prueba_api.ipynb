# %%
import requests
import json

user = "John Wick"

URL = "http://localhost:8080/{}".format(user)


data = requests.get(url = URL).json()

# %%
# Out:
# oid': '5de2abc42dc4e7d302be2501'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2abc42dc4e7d302be2503'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b251a'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b251c'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b251e'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b2520'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b2522'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b2539'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b253b'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b253d'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b253f'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2abdf24e02abe597b2541'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857ae'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857b0'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857b2'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857b4'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857b6'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857cd'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857cf'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857d1'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857d3'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2abf2d5249837fbe857d5'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d252'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d254'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d256'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d258'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d25a'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d271'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d273'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d275'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d277'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2ac4bfdd819d491a7d279'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2aca1dee24886006d4205'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2aca1dee24886006d4207'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2aca1dee24886006d4209'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2aca1dee24886006d420b'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2aca1dee24886006d420d'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2aca1dee24886006d4224'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2aca1dee24886006d4226'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2aca1dee24886006d4228'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2aca1dee24886006d422a'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2aca1dee24886006d422c'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b53'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b55'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b57'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b59'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b5b'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b72'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b74'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b76'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b78'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2aeeac0d4499f44c21b7a'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0ea8'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0eaa'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0eac'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0eae'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0eb0'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0ec7'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0ec9'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0ecb'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0ecd'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2af492e53a3016f7b0ecf'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2afa04531ed4091e6262a'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2afa04531ed4091e6262c'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2afa04531ed4091e6262e'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2afa04531ed4091e62630'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2afa04531ed4091e62632'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2afa04531ed4091e62649'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2afa04531ed4091e6264b'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2afa04531ed4091e6264d'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2afa04531ed4091e6264f'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2afa04531ed4091e62651'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164bba'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164bbc'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164bbe'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164bc0'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164bc2'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164bd9'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164bdb'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164bdd'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164bdf'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2b2c6578c8445a4164be1'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe89b'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe89d'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe89f'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe8a1'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe8a3'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe8ba'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe8bc'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe8be'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe8c0'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2b94b7163ce98874fe8c2'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'},
#  {'_id': {'$oid': '5de2beced788c5db24e4744d'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': {'$oid': '5de2beced788c5db24e4744f'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': {'$oid': '5de2beced788c5db24e47451'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 4,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:19:41',
#   'text': 'No way! 😮️'},
#  {'_id': {'$oid': '5de2beced788c5db24e47453'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 6,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:21:41',
#   'text': 'I bet people went crazy'},
#  {'_id': {'$oid': '5de2beced788c5db24e47455'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 8,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:23:41',
#   'text': 'Motherfucker! Hungover? 😵️'},
#  {'_id': {'$oid': '5de2beced788c5db24e4746c'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 31,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:16:41',
#   'text': 'Sure, boss.'},
#  {'_id': {'$oid': '5de2beced788c5db24e4746e'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 33,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:18:41',
#   'text': 'I do! I just dont feel appreciated in my job'},
#  {'_id': {'$oid': '5de2beced788c5db24e47470'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 35,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:20:41',
#   'text': 'I dunno...'},
#  {'_id': {'$oid': '5de2beced788c5db24e47472'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 37,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:22:41',
#   'text': 'Maybe'},
#  {'_id': {'$oid': '5de2beced788c5db24e47474'},
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 39,
#   'idChat': 3,
#   'datetime': '2019-10-20 10:24:41',
#   'text': 'Thank you, boss! I feel much better...'}]

# %%
requests.post('http://localhost:8080/add')
# Out:
# <Response [405]>
